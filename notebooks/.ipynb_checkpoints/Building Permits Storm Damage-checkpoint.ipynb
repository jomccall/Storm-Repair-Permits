# %% [markdown]
# # Seasonality and Time Lag Trend in Nashville Building Permit Data

# %% [markdown]
# ###### Imports and Defaults

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from warnings import simplefilter
import numpy as np
from shapely.geometry import Point
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.deterministic import DeterministicProcess

simplefilter("ignore")  # ignore warnings to clean up output cells

# %%
# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True, figsize=(11, 5))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## API Call

# %% [markdown]
# Create your API call through the SODA API by creating a variable called *endpoint* and a dictionary of *parameters* that can both include the columns you want and filters by whatever columns you want. Here I want all of the data, but I don't need every column. The API Guide can be found here:
#
# https://dev.socrata.com/foundry/data.nashville.gov/3h5w-q8b7

# %%
#endpoint variable
endpoint = 'https://data.nashville.gov/resource/3h5w-q8b7.json'

# %%
#the only params we need are the columns, I want the ivr_trk as the unique id, type and subtype description, date issued, value of construction, 
#address, zip, council district, purpose, mapped location
#also set the limit high so the downloads don't cut off
params = {'$select': 'ivr_trk, council_dist, permit_type_description, permit_subtype_description, date_issued, const_cost, address, purpose, mapped_location', 
         '$limit': 50000}
response = requests.get(endpoint, params = params)
response.status_code
# Out:
# 200

# %%
data = response.json()
data = pd.DataFrame(data)
print(data.shape)
data.head(3)
# Out:
# (34260, 9)
#    ivr_trk council_dist                  permit_type_description  \
# 0  3977347           26  Building Residential Rehab Storm Damage
# 1  3963014            5               Building Residential - New
# 2  3979526           18              Building Commercial - Rehab
#
#            permit_subtype_description              date_issued const_cost  \
# 0             Single Family Residence  2021-06-21T00:00:00.000      40000
# 1             Single Family Residence  2021-05-05T00:00:00.000     292188
# 2  Retail, Department / Retail Stores  2021-06-21T00:00:00.000     234501
#
#             address                                            purpose  \
# 0    5045  SUTER DR  to conduct general repairs to existing residen...
# 1     1807  JOY CIR  to construct a single family residence with 24...
# 2  2707  12TH AVE S  TO CONDUCT INTERIOR RENOVATIONS FOR NEW TENANT...
#
#                                      mapped_location
# 0  {'latitude': '36.068916', 'longitude': '-86.73...
# 1  {'latitude': '36.202582', 'longitude': '-86.76...
# 2  {'latitude': '36.122666', 'longitude': '-86.79...

# %% [markdown]
# ## Data Cleaning, Create Geodataframe

# %% [markdown]
# Rename columns

# %%
data.columns = ['id','dist','type','subtype','date','cost','address','purpose','location']

# %%
data.dropna()
# Out:
#             id dist                                     type  \
# 0      3977347   26  Building Residential Rehab Storm Damage
# 1      3963014    5               Building Residential - New
# 2      3979526   18              Building Commercial - Rehab
# 3      4008119    3             Building Residential - Rehab
# 4      3970804   29               Building Residential - New
# ...        ...  ...                                      ...
# 34255  3774006   18               Building Demolition Permit
# 34256  3903060   17              Building Commercial - Rehab
# 34257  3817298   21                Building Commercial - New
# 34258  3900938   17               Building Demolition Permit
# 34259  3711504   19  Building Commercial - Tenant Finish Out
#
#                                         subtype                     date  \
# 0                       Single Family Residence  2021-06-21T00:00:00.000
# 1                       Single Family Residence  2021-05-05T00:00:00.000
# 2            Retail, Department / Retail Stores  2021-06-21T00:00:00.000
# 3                       Single Family Residence  2021-08-05T00:00:00.000
# 4      Multifamily, Apt / Twnhome > 5 Unit Bldg  2021-06-21T00:00:00.000
# ...                                         ...                      ...
# 34255           Demolition Permit - Residential  2020-03-05T00:00:00.000
# 34256     General Office, Professional Services  2021-03-18T00:00:00.000
# 34257             Leasing / Sales Office, Other  2020-09-30T00:00:00.000
# 34258           Demolition Permit - Residential  2020-12-21T00:00:00.000
# 34259   Multifamily, Tri-Plex, Quad, Apartments  2020-06-25T00:00:00.000
#
#           cost                         address  \
# 0        40000                  5045  SUTER DR
# 1       292188                   1807  JOY CIR
# 2       234501                2707  12TH AVE S
# 3       103895                216  SOLNESS AVE
# 4      1001442  2760  MURFREESBORO PIKE  38-44
# ...        ...                             ...
# 34255     2900               1704  BERNARD AVE
# 34256    20000                1513  16TH AVE S
# 34257   201675                  1825  PEARL ST
# 34258    10000                 1611  MARTIN ST
# 34259  1054674                805  DIVISION ST
#
#                                                  purpose  \
# 0      to conduct general repairs to existing residen...
# 1      to construct a single family residence with 24...
# 2      TO CONDUCT INTERIOR RENOVATIONS FOR NEW TENANT...
# 3      Convert partially finished attic space to full...
# 4      To construct townhome units 38-44.  7 2 bedroo...
# ...                                                  ...
# 34255  to demolish existing residence.  not to be bur...
# 34256  partial demo of rear wall and finish \nPOC HAM...
# 34257  To locate a temporary 24 x 68 modular medical ...
# 34258  to demolish existing single family residence. ...
# 34259  Phase 22  17 apartments for  VANTAGE GULCH\nLe...
#
#                                                 location
# 0      {'latitude': '36.068916', 'longitude': '-86.73...
# 1      {'latitude': '36.202582', 'longitude': '-86.76...
# 2      {'latitude': '36.122666', 'longitude': '-86.79...
# 3      {'latitude': '36.242486', 'longitude': '-86.82...
# 4      {'latitude': '36.068505', 'longitude': '-86.63...
# ...                                                  ...
# 34255  {'latitude': '36.132', 'longitude': '-86.79660...
# 34256  {'latitude': '36.138594', 'longitude': '-86.79...
# 34257  {'latitude': '36.158405', 'longitude': '-86.80...
# 34258  {'latitude': '36.136665', 'longitude': '-86.77...
# 34259  {'latitude': '36.149927', 'longitude': '-86.78...
#
# [33761 rows x 9 columns]

# %% [markdown]
# Let's check out location, it appears to be a dictionary

# %%
type(data['location'][0])
# Out:
# dict

# %% [markdown]
# Use a lambda function to....?

# %%
data['location'].head().apply(lambda x: x['latitude'])
# Out:
# 0    36.068916
# 1    36.202582
# 2    36.122666
# 3    36.242486
# 4    36.068505
# Name: location, dtype: object

# %% [markdown]
# You come up against issues if some of the data doesn't have the location in there, so we're gonna create an empty list and use a for loop to find these rows

# %%
no_lat = []
for ind, val in data['location'].iteritems():
    try:
        val['latitude']
    except:
        print(ind, val)
        no_lat.append(ind)
# Out:
# 7 {'human_address': '{"address": "715 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 8 {'human_address': '{"address": "729 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 34 {'human_address': '{"address": "732 INSPIRATION BLVD 1", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 38 {'human_address': '{"address": "718 INSPIRATION BLVD", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 43 {'human_address': '{"address": "712 INSPIRATION BLVD", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 45 {'human_address': '{"address": "732 INSPIRATION BLVD 2", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 49 {'human_address': '{"address": "732 INSPIRATION BLVD 6", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 51 {'human_address': '{"address": "716 INSPIRATION BLVD", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 53 {'human_address': '{"address": "732 INSPIRATION BLVD 4", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 55 {'human_address': '{"address": "714 INSPIRATION BLVD", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 57 {'human_address': '{"address": "732 INSPIRATION BLVD 7", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 59 {'human_address': '{"address": "732 INSPIRATION BLVD 5", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 61 {'human_address': '{"address": "1024 NAVE CT", "city": "NASHVILLE", "state": "TN", "zip": "37214"}'}
# 63 {'human_address': '{"address": "732 INSPIRATION BLVD 3", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 67 {'human_address': '{"address": "710 INSPIRATION BLVD", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 79 {'human_address': '{"address": "1822A2 5TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 85 {'human_address': '{"address": "1001 HEALTH PARK DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 87 {'human_address': '{"address": "1400 WESTCHESTER DR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 101 {'human_address': '{"address": "2625 OLD BUENA VISTA RD", "city": "NASHVILLE", "state": "TN", "zip": "37218"}'}
# 103 {'human_address': '{"address": "152 LENHAM DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 115 {'human_address': '{"address": "145 LENHAM DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 116 {'human_address': '{"address": "908 CHICK CT", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 128 {'human_address': '{"address": "149 LENHAM DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 130 {'human_address': '{"address": "158 LENHAM DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 135 {'human_address': '{"address": "407B2 S 10TH ST", "city": "NASHVILLE", "state": "TN", "zip": "37206"}'}
# 140 {'human_address': '{"address": "5055 BROADWAY PL", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 143 {'human_address': '{"address": "407A2 S 10TH ST", "city": "NASHVILLE", "state": "TN", "zip": "37206"}'}
# 147 {'human_address': '{"address": "1110A2 N 6TH ST", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 148 {'human_address': '{"address": "144 LENHAM DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 151 {'human_address': '{"address": "1049 GRANBERY PARK DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 155 {'human_address': '{"address": "2720 OLD LEBANON PIKE 107", "city": "NASHVILLE", "state": "TN", "zip": "37214"}'}
# 195 {'human_address': '{"address": "2613 COFFENBERRY LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 198 {'human_address': '{"address": "827 SUNSET VIEW DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 206 {'human_address': '{"address": "329 WHISPERING WINDS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 212 {'human_address': '{"address": "825 SUNSET VIEW DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 222 {'human_address': '{"address": "4236 MAGNOLIA FARMS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 226 {'human_address': '{"address": "4221 MAGNOLIA FARMS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 233 {'human_address': '{"address": "4237 MAGNOLIA FARMS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 249 {'human_address': '{"address": "162 LENHAM DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 252 {'human_address': '{"address": "2704 HUNTMERE LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 264 {'human_address': '{"address": "2708 HUNTMERE LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 270 {'human_address': '{"address": "735 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 276 {'human_address': '{"address": "7655 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 310 {'human_address': '{"address": "7657 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 313 {'human_address': '{"address": "7648 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 319 {'human_address': '{"address": "7646 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 320 {'human_address': '{"address": "7700 STAPLETON CHASE DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 324 {'human_address': '{"address": "7650 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 335 {'human_address': '{"address": "7651 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 337 {'human_address': '{"address": "300 BAR B QUE ALY", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 344 {'human_address': '{"address": "7649 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 349 {'human_address': '{"address": "7653 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 350 {'human_address': '{"address": "0 44TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 353 {'human_address': '{"address": "29 ROEHRIG CT", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 354 {'human_address': '{"address": "33 ROEHRIG CT", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 373 {'human_address': '{"address": "25 ROEHRIG CT", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 378 {'human_address': '{"address": "883 INDUSTRIAL DR", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 380 {'human_address': '{"address": "881 INDUSTRIAL DR", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 393 {'human_address': '{"address": "2248 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 398 {'human_address': '{"address": "2268 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 399 {'human_address': '{"address": "731 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 400 {'human_address': '{"address": "2276 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 403 {'human_address': '{"address": "1101 KNOBCREST CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 413 {'human_address': '{"address": "2272 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 415 {'human_address': '{"address": "2267 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 419 {'human_address': '{"address": "2260 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 424 {'human_address': '{"address": "330 PENNINGTON CENTRE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37214"}'}
# 429 {'human_address': '{"address": "4121 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 437 {'human_address': '{"address": "4116 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 442 {'human_address': '{"address": "4120 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 445 {'human_address': '{"address": "4125 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 462 {'human_address': '{"address": "1025B2 BATTERY LN", "city": "NASHVILLE", "state": "TN", "zip": "37220"}'}
# 470 {'human_address': '{"address": "602 LAKE RESERVE CV", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 485 {'human_address': '{"address": "120 GREENOCK ALY", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 490 {'human_address': '{"address": "318 WALKER TER 7", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 491 {'human_address': '{"address": "318 WALKER TER 21", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 495 {'human_address': '{"address": "1400 ARTHUR AVE 1", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 503 {'human_address': '{"address": "318 WALKER TER 28", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 507 {'human_address': '{"address": "2028 MORRISON RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 513 {'human_address': '{"address": "2020 MORRISON RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 515 {'human_address': '{"address": "1921 GALLATIN PIKE N 2", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 520 {'human_address': '{"address": "2026 MORRISON RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 522 {'human_address': '{"address": "2032 MORRISON RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 533 {'human_address': '{"address": "816 REGIMENTAL DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 534 {'human_address': '{"address": "2030 MORRISON RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 540 {'human_address': '{"address": "2024 MORRISON RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 544 {'human_address': '{"address": "2022 MORRISON RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 577 {'human_address': '{"address": "600 LAKE RESERVE CV", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 581 {'human_address': '{"address": "604 LAKE RESERVE CV", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 584 {'human_address': '{"address": "87 HICKERSON ST", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 586 {'human_address': '{"address": "625B HENRY LN", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 592 {'human_address': '{"address": "823 TWIN FALLS DR", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 603 {'human_address': '{"address": "2430 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 605 {'human_address': '{"address": "809 REGIMENTAL DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 607 {'human_address': '{"address": "2426 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 616 {'human_address': '{"address": "2424 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 627 {'human_address': '{"address": "2422 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 631 {'human_address': '{"address": "827 TWIN FALLS DR", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 641 {'human_address': '{"address": "7673 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 645 {'human_address': '{"address": "2428 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 646 {'human_address': '{"address": "971 FANCHER LN", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 650 {'human_address': '{"address": "83 HICKERSON ST", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 664 {'human_address': '{"address": "2280 SEVEN POINTS CIR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 673 {'human_address': '{"address": "7208 STILL SPRING HOLLOW DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 677 {'human_address': '{"address": "6565 FRYE LN", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 680 {'human_address': '{"address": "0 CATO RD", "city": "NASHVILLE", "state": "TN", "zip": "37218"}'}
# 682 {'human_address': '{"address": "6445 ARMSTRONG DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 688 {'human_address': '{"address": "6569 FRYE LN", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 690 {'human_address': '{"address": "6441 ARMSTRONG DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 699 {'human_address': '{"address": "6599 FRYE LN", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 719 {'human_address': '{"address": "335 24TH AVE N 100", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 729 {'human_address': '{"address": "983 FANCHER LN", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 730 {'human_address': '{"address": "7229 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 741 {'human_address': '{"address": "1812B2 5TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 751 {'human_address': '{"address": "7602 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 756 {'human_address': '{"address": "7632 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 758 {'human_address': '{"address": "7215 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 759 {'human_address': '{"address": "721B ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 761 {'human_address': '{"address": "7612 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 764 {'human_address': '{"address": "7681 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 766 {'human_address': '{"address": "7607 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 768 {'human_address': '{"address": "7635 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 771 {'human_address': '{"address": "7213 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 774 {'human_address': '{"address": "7211 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 776 {'human_address': '{"address": "7217 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 777 {'human_address': '{"address": "7614 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 781 {'human_address': '{"address": "7630 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 782 {'human_address': '{"address": "7231 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 784 {'human_address': '{"address": "7616 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 786 {'human_address': '{"address": "7634 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 790 {'human_address': '{"address": "7624 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 791 {'human_address': '{"address": "7619 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 792 {'human_address': '{"address": "7608 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 795 {'human_address': '{"address": "7683 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 797 {'human_address': '{"address": "7633 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 798 {'human_address': '{"address": "7617 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 800 {'human_address': '{"address": "7611 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 801 {'human_address': '{"address": "7600 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 802 {'human_address': '{"address": "719 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 803 {'human_address': '{"address": "7606 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 804 {'human_address': '{"address": "7626 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 805 {'human_address': '{"address": "7613 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 806 {'human_address': '{"address": "7621 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 807 {'human_address': '{"address": "7209 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 808 {'human_address': '{"address": "7618 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 810 {'human_address': '{"address": "7622 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 814 {'human_address': '{"address": "7697 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 817 {'human_address': '{"address": "7604 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 819 {'human_address': '{"address": "7601 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 820 {'human_address': '{"address": "7623 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 821 {'human_address': '{"address": "0 MCCRORY CREEK RD", "city": "NASHVILLE", "state": "TN", "zip": "37214"}'}
# 822 {'human_address': '{"address": "7610 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 825 {'human_address': '{"address": "7233 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 828 {'human_address': '{"address": "7677 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 829 {'human_address': '{"address": "7628 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 833 {'human_address': '{"address": "7627 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 834 {'human_address': '{"address": "7620 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 835 {'human_address': '{"address": "7637 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 837 {'human_address': '{"address": "7603 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 838 {'human_address': '{"address": "7605 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 840 {'human_address': '{"address": "7227 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 841 {'human_address': '{"address": "7625 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 843 {'human_address': '{"address": "7675 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 846 {'human_address': '{"address": "7629 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 849 {'human_address': '{"address": "7687 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 851 {'human_address': '{"address": "7631 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 853 {'human_address': '{"address": "733 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 858 {'human_address': '{"address": "0 WATERSIDE DR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 879 {'human_address': '{"address": "831 TWIN FALLS DR", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 884 {'human_address': '{"address": "2028 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 885 {'human_address': '{"address": "6003A2 CALIFORNIA AVE", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 887 {'human_address': '{"address": "2060 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 891 {'human_address': '{"address": "2032 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 894 {'human_address': '{"address": "2040 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 899 {'human_address': '{"address": "2036 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 917 {'human_address': '{"address": "7679 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 935 {'human_address': '{"address": "7695 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 948 {'human_address': '{"address": "6003B2 CALIFORNIA AVE", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 949 {'human_address': '{"address": "2044 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 969 {'human_address': '{"address": "1042A2 SCOVEL ST", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 971 {'human_address': '{"address": "2709 HUNTMERE LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 973 {'human_address': '{"address": "2048 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 976 {'human_address': '{"address": "2064 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 978 {'human_address': '{"address": "980 FANCHER LN", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 986 {'human_address': '{"address": "1042B2 SCOVEL ST", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 987 {'human_address': '{"address": "2024 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 990 {'human_address': '{"address": "4054 ARROWLEAF LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 991 {'human_address': '{"address": "943 FANCHER LN", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 1008 {'human_address': '{"address": "4058 ARROWLEAF LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1032 {'human_address': '{"address": "101 HAILEY DR", "city": "NASHVILLE", "state": "TN", "zip": "37204"}'}
# 1050 {'human_address': '{"address": "2021A3 10TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 1067 {'human_address': '{"address": "640 21ST AVE N 128 B", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 1068 {'human_address': '{"address": "2021B3 10TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 1115 {'human_address': '{"address": "2625 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1116 {'human_address': '{"address": "1021 VIDA WAY 201", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1117 {'human_address': '{"address": "830 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1120 {'human_address': '{"address": "2705 HUNTMERE LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1122 {'human_address': '{"address": "2608 LANDCREST CT", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 1124 {'human_address': '{"address": "2713 HUNTMERE LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1125 {'human_address': '{"address": "5816 WOODLAND HILLS DR", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 1131 {'human_address': '{"address": "2665 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1133 {'human_address': '{"address": "605 PRESS PL 160 B", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 1135 {'human_address': '{"address": "1316 GRANDVIEW AVE", "city": "NASHVILLE", "state": "TN", "zip": "37215"}'}
# 1136 {'human_address': '{"address": "836 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1138 {'human_address': '{"address": "2661 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1144 {'human_address': '{"address": "737 SUMMIT OAKS CT", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 1146 {'human_address': '{"address": "110B2 FERN AVE", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1154 {'human_address': '{"address": "4873 CHUTNEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1160 {'human_address': '{"address": "4861 CHUTNEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1162 {'human_address': '{"address": "4136 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1164 {'human_address': '{"address": "826 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1167 {'human_address': '{"address": "1245 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1170 {'human_address': '{"address": "1247 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1175 {'human_address': '{"address": "2431 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 1178 {'human_address': '{"address": "2032 KIRKWALL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1181 {'human_address': '{"address": "828 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1182 {'human_address': '{"address": "1241 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1185 {'human_address': '{"address": "824 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1187 {'human_address': '{"address": "2024 KIRKWALL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1190 {'human_address': '{"address": "2036 KIRKWALL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1192 {'human_address': '{"address": "1021 VIDA WAY 101", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1193 {'human_address': '{"address": "820 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1194 {'human_address': '{"address": "2433 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 1197 {'human_address': '{"address": "2439 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 1199 {'human_address': '{"address": "837 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1200 {'human_address': '{"address": "2401 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1201 {'human_address': '{"address": "834 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1206 {'human_address': '{"address": "822 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1207 {'human_address': '{"address": "835 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1208 {'human_address': '{"address": "401 BLUEWATER DR", "city": "NASHVILLE", "state": "TN", "zip": "37217"}'}
# 1213 {'human_address': '{"address": "400 BLUEWATER DR", "city": "NASHVILLE", "state": "TN", "zip": "37217"}'}
# 1215 {'human_address': '{"address": "1021 VIDA WAY 202", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1216 {'human_address': '{"address": "404 BLUEWATER DR", "city": "NASHVILLE", "state": "TN", "zip": "37217"}'}
# 1217 {'human_address': '{"address": "1243 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1218 {'human_address': '{"address": "1021 VIDA WAY 102", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1220 {'human_address': '{"address": "838 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1222 {'human_address': '{"address": "2437 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 1223 {'human_address': '{"address": "833 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1224 {'human_address': '{"address": "1239 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1228 {'human_address': '{"address": "832 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1230 {'human_address': '{"address": "831 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1232 {'human_address': '{"address": "2429 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 1233 {'human_address': '{"address": "2435 SAYERVILLE AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 1240 {'human_address': '{"address": "409 BLUEWATER DR", "city": "NASHVILLE", "state": "TN", "zip": "37217"}'}
# 1243 {'human_address': '{"address": "408 BLUEWATER DR", "city": "NASHVILLE", "state": "TN", "zip": "37217"}'}
# 1244 {'human_address': '{"address": "829 SHERWOOD COMMONS WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1253 {'human_address': '{"address": "4865 CHUTNEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1265 {'human_address': '{"address": "4137 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1269 {'human_address': '{"address": "4141 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1270 {'human_address': '{"address": "4860 CHUTNEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1272 {'human_address': '{"address": "4869 CHUTNEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1280 {'human_address': '{"address": "2728B2 HERMAN ST", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 1284 {'human_address': '{"address": "405 BLUEWATER DR", "city": "NASHVILLE", "state": "TN", "zip": "37217"}'}
# 1292 {'human_address': '{"address": "515 HOBSON CHAPEL PL", "city": "NASHVILLE", "state": "TN", "zip": "37206"}'}
# 1298 {'human_address': '{"address": "2609 COFFENBERRY LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1311 {'human_address': '{"address": "821 BOLTON DR", "city": "NASHVILLE", "state": "TN", "zip": "37135"}'}
# 1313 {'human_address': '{"address": "819 BOLTON DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1314 {'human_address': '{"address": "2609 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1317 {'human_address': '{"address": "2629 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1331 {'human_address': '{"address": "817 BOLTON DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1338 {'human_address': '{"address": "2529 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1343 {'human_address': '{"address": "2728A2 HERMAN ST", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 1344 {'human_address': '{"address": "4864 CHUTNEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1345 {'human_address': '{"address": "4856 CHUTNEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1351 {'human_address': '{"address": "3510 HILLDALE DR", "city": "NASHVILLE", "state": "TN", "zip": "37215"}'}
# 1359 {'human_address': '{"address": "101 AIRPARK CTR E 101", "city": "NASHVILLE", "state": "TN", "zip": "37217"}'}
# 1390 {'human_address': '{"address": "717 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1391 {'human_address': '{"address": "2637 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1393 {'human_address': '{"address": "723B ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1396 {'human_address': '{"address": "115 GREAT CIRCLE RD 100 B", "city": "NASHVILLE", "state": "TN", "zip": "37228"}'}
# 1402 {'human_address': '{"address": "2652 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1414 {'human_address': '{"address": "1404 WESTCHESTER DR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1418 {'human_address': '{"address": "310 BECANNI LN", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1428 {'human_address': '{"address": "2123B2 12TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 1438 {'human_address': '{"address": "2673 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1441 {'human_address': '{"address": "314 BECANNI LN", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1471 {'human_address': '{"address": "3334 TASKER DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1474 {'human_address': '{"address": "3336 TASKER DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1499 {'human_address': '{"address": "3338 TASKER DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1501 {'human_address': '{"address": "2028 KIRKWALL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1502 {'human_address': '{"address": "7685 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1514 {'human_address': '{"address": "4145 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1516 {'human_address': '{"address": "312 BECANNI LN", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1521 {'human_address': '{"address": "2648 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1525 {'human_address': '{"address": "308 BECANNI LN", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1535 {'human_address': '{"address": "4908A2 MICHIGAN AVE", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1540 {'human_address': '{"address": "723A ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1541 {'human_address': '{"address": "721A ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1546 {'human_address': '{"address": "737 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1550 {'human_address': '{"address": "727 ARBOR TRACE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1560 {'human_address': '{"address": "2279 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1563 {'human_address': '{"address": "2935 WINTERBERRY DR 33", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 1564 {'human_address': '{"address": "1251 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1566 {'human_address': '{"address": "1257 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1571 {'human_address': '{"address": "4117 TREEHAVEN PL", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1572 {'human_address': '{"address": "2212 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1573 {'human_address': '{"address": "6249 CRAWFORD DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 1575 {'human_address': '{"address": "1259 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1576 {'human_address': '{"address": "1253 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1581 {'human_address': '{"address": "1255 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1587 {'human_address': '{"address": "2205 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1588 {'human_address': '{"address": "1261 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1589 {'human_address': '{"address": "1249 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1591 {'human_address': '{"address": "3517 FOUR LEAF WAY", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1594 {'human_address': '{"address": "0 UNKNOWN", "city": "NASHVILLE", "state": "TN", "zip": "00000"}'}
# 1605 {'human_address': '{"address": "2216 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1607 {'human_address': '{"address": "2221 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1619 {'human_address': '{"address": "0 OLD FRANKLIN RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1628 {'human_address': '{"address": "759B GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1636 {'human_address': '{"address": "2420 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1638 {'human_address': '{"address": "2408 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1641 {'human_address': '{"address": "2422 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1645 {'human_address': '{"address": "2426 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1652 {'human_address': '{"address": "519 27TH AVE N 101", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1658 {'human_address': '{"address": "1278 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1659 {'human_address': '{"address": "313 WHISPERING WINDS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 1660 {'human_address': '{"address": "7115 SOUTHPOINT PKWY", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 1671 {'human_address': '{"address": "5213B2 ILLINOIS AVE", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1672 {'human_address': '{"address": "4228 MAGNOLIA FARMS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 1689 {'human_address': '{"address": "717 GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1691 {'human_address': '{"address": "154 BURKITT COMMONS AVE", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1697 {'human_address': '{"address": "7691 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1700 {'human_address': '{"address": "5055 BROADWAY PL", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 1704 {'human_address': '{"address": "1007 MILSON LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1707 {'human_address': '{"address": "2123A2 12TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 1711 {'human_address': '{"address": "152 BURKITT COMMONS AVE", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1715 {'human_address': '{"address": "1013 MILSON LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1719 {'human_address': '{"address": "1003 MILSON LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1720 {'human_address': '{"address": "1009 MILSON LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1721 {'human_address': '{"address": "1005 MILSON LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1724 {'human_address': '{"address": "2418 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1725 {'human_address': '{"address": "150 BURKITT COMMONS AVE", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1730 {'human_address': '{"address": "1011 MILSON LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1731 {'human_address': '{"address": "7689 GUNNERS LANDING DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1732 {'human_address': '{"address": "703 GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1734 {'human_address': '{"address": "156 BURKITT COMMONS AVE", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1735 {'human_address': '{"address": "705 GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1739 {'human_address': '{"address": "713 GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1740 {'human_address': '{"address": "709 GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1746 {'human_address': '{"address": "1011B MILSON LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1749 {'human_address': '{"address": "7225 CARRIE CT", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1752 {'human_address': '{"address": "1274 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1757 {'human_address': '{"address": "1280 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1765 {'human_address': '{"address": "1272 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1768 {'human_address': '{"address": "2424 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1778 {'human_address': '{"address": "757B GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1788 {'human_address': '{"address": "1276 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1790 {'human_address': '{"address": "1270 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1795 {'human_address': '{"address": "0 HOBSON PIKE", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1803 {'human_address': '{"address": "2406 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1804 {'human_address': '{"address": "2402 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1827 {'human_address': '{"address": "2410 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1834 {'human_address': '{"address": "753B GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1835 {'human_address': '{"address": "749B GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1836 {'human_address': '{"address": "1504 CARLYBROOKE LN", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 1855 {'human_address': '{"address": "751B GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1857 {'human_address': '{"address": "755B GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 1861 {'human_address': '{"address": "2400 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1863 {'human_address': '{"address": "2404 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1864 {'human_address': '{"address": "2414 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1871 {'human_address': '{"address": "2416 DANILYNN DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 1874 {'human_address': '{"address": "4908B2 MICHIGAN AVE", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1880 {'human_address': '{"address": "2157 CHADWELL RETREAT DR", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1885 {'human_address': '{"address": "318 WALKER TER 19", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1887 {'human_address': '{"address": "318 WALKER TER 8", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1892 {'human_address': '{"address": "318 WALKER TER 17", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1894 {'human_address': '{"address": "328 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1898 {'human_address': '{"address": "314 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1901 {'human_address': '{"address": "318 WALKER TER 10", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1902 {'human_address': '{"address": "318 WALKER TER 26", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1905 {'human_address': '{"address": "326 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1907 {'human_address': '{"address": "320 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1908 {'human_address': '{"address": "115 GREAT CIRCLE RD 301-382", "city": "NASHVILLE", "state": "TN", "zip": "37228"}'}
# 1909 {'human_address': '{"address": "302 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1910 {'human_address': '{"address": "324 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1912 {'human_address': '{"address": "306 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1913 {'human_address': '{"address": "115 GREAT CIRCLE RD", "city": "NASHVILLE", "state": "TN", "zip": "37228"}'}
# 1915 {'human_address': '{"address": "318 WALKER TER 27", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1917 {'human_address': '{"address": "332 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1919 {'human_address': '{"address": "318 WALKER TER 24", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1920 {'human_address': '{"address": "318 WALKER TER 6", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1921 {'human_address': '{"address": "318 WALKER TER 18", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1922 {'human_address': '{"address": "115 GREAT CIRCLE RD 201-278", "city": "NASHVILLE", "state": "TN", "zip": "37228"}'}
# 1925 {'human_address': '{"address": "115 GREAT CIRCLE RD 104-173", "city": "NASHVILLE", "state": "TN", "zip": "37228"}'}
# 1928 {'human_address': '{"address": "318 WALKER TER 5", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1931 {'human_address': '{"address": "312 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1932 {'human_address': '{"address": "304 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1934 {'human_address': '{"address": "318 WALKER TER 9", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1935 {'human_address': '{"address": "2151 CHADWELL RETREAT DR", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1937 {'human_address': '{"address": "318 WALKER TER 11", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1939 {'human_address': '{"address": "318 WALKER TER 29", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1943 {'human_address': '{"address": "318 WALKER TER 4", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1944 {'human_address': '{"address": "310 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1946 {'human_address': '{"address": "318 WALKER TER 20", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1947 {'human_address': '{"address": "318 WALKER TER 22", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1948 {'human_address': '{"address": "318 WALKER TER 13", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1950 {'human_address': '{"address": "334 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1952 {'human_address': '{"address": "318 WALKER TER 2", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1953 {'human_address': '{"address": "330 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1954 {'human_address': '{"address": "318 WALKER TER 15", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1957 {'human_address': '{"address": "336 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1960 {'human_address': '{"address": "316 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1961 {'human_address': '{"address": "338 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1962 {'human_address': '{"address": "318 WALKER TER 23", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1964 {'human_address': '{"address": "318 WALKER TER 14", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1965 {'human_address': '{"address": "318 WALKER TER 12", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1966 {'human_address': '{"address": "318 WALKER TER 16", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1969 {'human_address': '{"address": "308 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1970 {'human_address': '{"address": "115 GREAT CIRCLE RD", "city": "NASHVILLE", "state": "TN", "zip": "37228"}'}
# 1971 {'human_address': '{"address": "2153 CHADWELL RETREAT DR", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1973 {'human_address': '{"address": "318 WALKER TER 1", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1974 {'human_address': '{"address": "2155 CHADWELL RETREAT DR", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1976 {'human_address': '{"address": "318 WALKER TER 25", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1977 {'human_address': '{"address": "300 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1980 {'human_address': '{"address": "318 WALKER TER 3", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1982 {'human_address': '{"address": "322 WALKER TER", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 1994 {'human_address': '{"address": "414B WESTBORO DR", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 1999 {'human_address': '{"address": "948 FANCHER LN", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 2005 {'human_address': '{"address": "901 CHICK CT", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 2006 {'human_address': '{"address": "947 MILLSTREAM DR", "city": "NASHVILLE", "state": "TN", "zip": "37218"}'}
# 2021 {'human_address': '{"address": "945 MILLSTREAM DR", "city": "NASHVILLE", "state": "TN", "zip": "37218"}'}
# 2028 {'human_address': '{"address": "1012B2 9TH AVE S", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 2029 {'human_address': '{"address": "4249 MAGNOLIA FARMS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 2050 {'human_address': '{"address": "905 CHICK CT", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 2051 {'human_address': '{"address": "900 CHICK CT", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 2053 {'human_address': '{"address": "57 HART ST JERNIGAN S", "city": "NASHVILLE", "state": "TN", "zip": "37210"}'}
# 2076 {'human_address': '{"address": "3862 OLD HICKORY BLVD", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 2077 {'human_address': '{"address": "813 TWIN FALLS DR", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 2094 {'human_address': '{"address": "2644 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 2098 {'human_address': '{"address": "2605 COFFENBERRY LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 2104 {'human_address': '{"address": "2632 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# ...
# 33442 {'human_address': '{"address": "223 MUIR AVE", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 33452 {'human_address': '{"address": "504 HOBSON CHAPEL PL", "city": "NASHVILLE", "state": "TN", "zip": "37206"}'}
# 33455 {'human_address': '{"address": "4969 CHUTNEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33468 {'human_address': '{"address": "832 SUNSET VIEW DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33496 {'human_address': '{"address": "1633 ALAYNA DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 33503 {'human_address': '{"address": "3265 LONGSTALK RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33520 {'human_address': '{"address": "3431 SHELBY BOTTOMS BND", "city": "NASHVILLE", "state": "TN", "zip": "37206"}'}
# 33526 {'human_address': '{"address": "2636 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 33528 {'human_address': '{"address": "2217 BELLE CREEK WAY", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 33529 {'human_address': '{"address": "4225 POLK FOREST CIR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 33530 {'human_address': '{"address": "2521 PRAIRIE HILL DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33532 {'human_address': '{"address": "2080 NOTCHLEAF RD", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33535 {'human_address': '{"address": "3419 SHELBY BOTTOMS BND", "city": "NASHVILLE", "state": "TN", "zip": "37206"}'}
# 33539 {'human_address': '{"address": "2518 GALLATIN AVE", "city": "NASHVILLE", "state": "TN", "zip": "37206"}'}
# 33551 {'human_address': '{"address": "1321A2 MERIDIAN ST", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 33552 {'human_address': '{"address": "3156 CHARLES PARK DR", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 33558 {'human_address': '{"address": "2159 CAREFREE LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33560 {'human_address': '{"address": "2102A2 PORTER RD", "city": "NASHVILLE", "state": "TN", "zip": "37206"}'}
# 33570 {'human_address': '{"address": "6005 TRAILWATER ALY", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33571 {'human_address': '{"address": "3396 WOODLAND STAR WAY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 33575 {'human_address': '{"address": "7092 WESTSIDE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37205"}'}
# 33581 {'human_address': '{"address": "2025 MORRISON RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 33582 {'human_address': '{"address": "7051 PAISLEY WOOD DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33583 {'human_address': '{"address": "1021 BRADBURN VILLAGE DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33589 {'human_address': '{"address": "1638 54TH AVE N 321", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 33599 {'human_address': '{"address": "5020 ARROGATE DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33602 {'human_address': '{"address": "2312 COUNTESS ALY", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 33614 {'human_address': '{"address": "169 BURKITT COMMONS AVE", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 33617 {'human_address': '{"address": "2244 BELLE CREEK WAY", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 33628 {'human_address': '{"address": "613 HADLEY VILLAGE BLVD", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 33630 {'human_address': '{"address": "5220 TUPELO ST", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33634 {'human_address': '{"address": "1108A2 GRANDVIEW DR", "city": "NASHVILLE", "state": "TN", "zip": "37204"}'}
# 33641 {'human_address': '{"address": "201 STERLING POINT CIR", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 33646 {'human_address': '{"address": "305 BODDINGTON LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33651 {'human_address': '{"address": "2127 CAREFREE LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33656 {'human_address': '{"address": "7212 CALDERWOOD DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 33658 {'human_address': '{"address": "2024 EDISON PARK LN", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 33659 {'human_address': '{"address": "1001 HEALTH PARK DR 600", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 33661 {'human_address': '{"address": "7372 BRADY LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33673 {'human_address': '{"address": "137 LENHAM DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 33674 {'human_address': '{"address": "805 SUNSET VIEW DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33675 {'human_address': '{"address": "1020 DR MARTIN L KING JR BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 33680 {'human_address': '{"address": "800 4TH AVE S 103", "city": "NASHVILLE", "state": "TN", "zip": "37210"}'}
# 33681 {'human_address': '{"address": "7133 SILVERWOOD TRL", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33697 {'human_address': '{"address": "812 SUNSET VIEW DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33709 {'human_address': '{"address": "714 MILL CREEK MEADOW DR", "city": "NASHVILLE", "state": "TN", "zip": "37214"}'}
# 33710 {'human_address': '{"address": "1009 BRADBURN VILLAGE DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33717 {'human_address': '{"address": "3013 WILTSHIRE PARK PL", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33721 {'human_address': '{"address": "2172 CAREFREE LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33740 {'human_address': '{"address": "1011 VIDA WAY 105", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 33748 {'human_address': '{"address": "4323 STONE HALL BLVD", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33754 {'human_address': '{"address": "709 BRADBURN VILLAGE WAY", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33780 {'human_address': '{"address": "2155 BAYPORT AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 33782 {'human_address': '{"address": "1515 WHITE TIP LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33795 {'human_address': '{"address": "3612 BROOKWAY DR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 33797 {'human_address': '{"address": "611 WALLACE CT", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 33803 {'human_address': '{"address": "1231 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33805 {'human_address': '{"address": "5230 TUPELO ST", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33819 {'human_address': '{"address": "5056 BROADWAY PL", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 33823 {'human_address': '{"address": "1510A2 10TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 33830 {'human_address': '{"address": "2126 BAYPORT AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 33831 {'human_address': '{"address": "1507A2 10TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 33832 {'human_address': '{"address": "4677 TROUSDALE DR MAPCO EXPR", "city": "NASHVILLE", "state": "TN", "zip": "37204"}'}
# 33839 {'human_address': '{"address": "4232 MAGNOLIA FARMS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33841 {'human_address': '{"address": "575 CREATIVE WAY", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 33845 {'human_address': '{"address": "1021 LAWSONS RIDGE DR", "city": "NASHVILLE", "state": "TN", "zip": "37218"}'}
# 33847 {'human_address': '{"address": "450 GLASTONBURY RD 15", "city": "NASHVILLE", "state": "TN", "zip": "37217"}'}
# 33849 {'human_address': '{"address": "1009 GRANBERY PARK DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 33855 {'human_address': '{"address": "2029 CAREFREE LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33860 {'human_address': '{"address": "2109 PRESERVE CIR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33864 {'human_address': '{"address": "1903A2 11TH AVE N", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 33869 {'human_address': '{"address": "355 KARA LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 33870 {'human_address': '{"address": "830 SUNSET VIEW DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33872 {'human_address': '{"address": "2807B2 WHITE OAK DR", "city": "NASHVILLE", "state": "TN", "zip": "37215"}'}
# 33875 {'human_address': '{"address": "424 PORTSDALE DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 33878 {'human_address': '{"address": "424 BECANNI LN", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 33887 {'human_address': '{"address": "808 SKYLINE RIDGE DR 701-724", "city": "MADISON", "state": "TN", "zip": "37115"}'}
# 33890 {'human_address': '{"address": "7115 SOUTHPOINT PKWY", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 33893 {'human_address': '{"address": "1544 HAMILTON CROSS DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33908 {'human_address': '{"address": "1021 MILSON LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 33910 {'human_address': '{"address": "1585 WINDING CREEK DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 33911 {'human_address': '{"address": "5340 TUPELO ST", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33915 {'human_address': '{"address": "2737 GOSSETT TRL", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 33924 {'human_address': '{"address": "821 SUNSET VIEW DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33931 {'human_address': '{"address": "1125 10TH AVE N 203", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 33940 {'human_address': '{"address": "3621 BROOKWAY DR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 33942 {'human_address': '{"address": "225 STERLING POINT CIR", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 33953 {'human_address': '{"address": "6054 BLACKBERRY RIDGE LN", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33969 {'human_address': '{"address": "1031 BRADBURN VILLAGE DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33983 {'human_address': '{"address": "1528 HAMILTON CROSS DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33984 {'human_address': '{"address": "6404 ARMSTRONG DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 33985 {'human_address': '{"address": "306A2 LUTIE ST", "city": "NASHVILLE", "state": "TN", "zip": "37210"}'}
# 33989 {'human_address': '{"address": "5213 TUPELO ST", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 33990 {'human_address': '{"address": "21 WHITE BRIDGE PIKE 107", "city": "NASHVILLE", "state": "TN", "zip": "37205"}'}
# 33991 {'human_address': '{"address": "1022 GRANBERY PARK DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 33998 {'human_address': '{"address": "542B2 HAMILTON AVE", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 34006 {'human_address': '{"address": "2134 BAYPORT AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 34012 {'human_address': '{"address": "219 MUIR AVE", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 34015 {'human_address': '{"address": "1652 ALAYNA DR", "city": "NASHVILLE", "state": "TN", "zip": "37221"}'}
# 34018 {'human_address': '{"address": "601 WALLACE CT", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 34023 {'human_address': '{"address": "4112 CRIMSON HOP DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34030 {'human_address': '{"address": "3920 ASHEFORD TRCE", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34031 {'human_address': '{"address": "5034 BROADWAY PL", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 34042 {'human_address': '{"address": "1608 MARSHALL HOLLOW DR", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 34044 {'human_address': '{"address": "4100 MAGNOLIA FARMS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 34053 {'human_address': '{"address": "7115 SOUTHPOINT PKWY 4", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 34054 {'human_address': '{"address": "841 WESTCOTT LN", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 34055 {'human_address': '{"address": "2321B FAIRCHILD CIR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 34068 {'human_address': '{"address": "7444 MARONEY DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34069 {'human_address': '{"address": "2338 PATRICK AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 34071 {'human_address': '{"address": "1524 HAMILTON CROSS DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34087 {'human_address': '{"address": "2015 AXIS AVE", "city": "OLD HICKORY", "state": "TN", "zip": "37138"}'}
# 34091 {'human_address': '{"address": "759 MILL CREEK MEADOW DR", "city": "NASHVILLE", "state": "TN", "zip": "37214"}'}
# 34111 {'human_address': '{"address": "7000 HARRIS HILLS LN", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 34114 {'human_address': '{"address": "4088 MAGNOLIA FARMS DR", "city": "HERMITAGE", "state": "TN", "zip": "37076"}'}
# 34117 {'human_address': '{"address": "934 GOVERNORS CT 207", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34118 {'human_address': '{"address": "648 HENRY LN", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 34122 {'human_address': '{"address": "1125 10TH AVE N 212", "city": "NASHVILLE", "state": "TN", "zip": "37208"}'}
# 34129 {'human_address': '{"address": "809 GOSWELL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 34131 {'human_address': '{"address": "2472 PRAIRIE HILL DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34139 {'human_address': '{"address": "934 GOVERNORS CT 202", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34140 {'human_address': '{"address": "2135 CAREFREE LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34145 {'human_address': '{"address": "312 HIDDEN SPRINGS CV", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 34148 {'human_address': '{"address": "2020 KIRKWALL DR", "city": "NOLENSVILLE", "state": "TN", "zip": "37135"}'}
# 34152 {'human_address': '{"address": "2005 CAREFREE LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34155 {'human_address': '{"address": "602 WALLACE CT", "city": "NASHVILLE", "state": "TN", "zip": "37211"}'}
# 34160 {'human_address': '{"address": "836 TWIN FALLS DR", "city": "JOELTON", "state": "TN", "zip": "37080"}'}
# 34166 {'human_address': '{"address": "500B PATH ALY", "city": "NOLENSVILLE", "state": "TN", "zip": "37215"}'}
# 34176 {'human_address': '{"address": "4109 CRIMSON HOP DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34189 {'human_address': '{"address": "2512 VISTA LN", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 34199 {'human_address': '{"address": "2605 THORNTON GROVE BLVD", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 34203 {'human_address': '{"address": "1638 54TH AVE N 303", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 34205 {'human_address': '{"address": "1209 COTTAGE VIEW LN", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34213 {'human_address': '{"address": "7000 WESTSIDE CIR", "city": "NASHVILLE", "state": "TN", "zip": "37205"}'}
# 34220 {'human_address': '{"address": "5530 CENTRAL GROVE SQ", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34224 {'human_address': '{"address": "1236 SHIRE DR", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 34225 {'human_address': '{"address": "1638 54TH AVE N 233", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 34228 {'human_address': '{"address": "2053 WESTCHESTER DR", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 34238 {'human_address': '{"address": "1638 54TH AVE N 319", "city": "NASHVILLE", "state": "TN", "zip": "37209"}'}
# 34239 {'human_address': '{"address": "2935 WINTERBERRY DR 42", "city": "NASHVILLE", "state": "TN", "zip": "37207"}'}
# 34240 {'human_address': '{"address": "962 ASHLAND PLACE DR", "city": "NASHVILLE", "state": "TN", "zip": "37218"}'}

# %%
no_lat
# Out:
# [7,
#  8,
#  34,
#  38,
#  43,
#  45,
#  49,
#  51,
#  53,
#  55,
#  57,
#  59,
#  61,
#  63,
#  67,
#  79,
#  85,
#  87,
#  101,
#  103,
#  115,
#  116,
#  128,
#  130,
#  135,
#  140,
#  143,
#  147,
#  148,
#  151,
#  155,
#  195,
#  198,
#  206,
#  212,
#  222,
#  226,
#  233,
#  249,
#  252,
#  264,
#  270,
#  276,
#  310,
#  313,
#  319,
#  320,
#  324,
#  335,
#  337,
#  344,
#  349,
#  350,
#  353,
#  354,
#  373,
#  378,
#  380,
#  393,
#  398,
#  399,
#  400,
#  403,
#  413,
#  415,
#  419,
#  424,
#  429,
#  437,
#  442,
#  445,
#  462,
#  470,
#  485,
#  490,
#  491,
#  495,
#  503,
#  507,
#  513,
#  515,
#  520,
#  522,
#  533,
#  534,
#  540,
#  544,
#  577,
#  581,
#  584,
#  586,
#  592,
#  603,
#  605,
#  607,
#  616,
#  627,
#  631,
#  641,
#  645,
#  646,
#  650,
#  664,
#  673,
#  677,
#  680,
#  682,
#  688,
#  690,
#  699,
#  719,
#  729,
#  730,
#  741,
#  751,
#  756,
#  758,
#  759,
#  761,
#  764,
#  766,
#  768,
#  771,
#  774,
#  776,
#  777,
#  781,
#  782,
#  784,
#  786,
#  790,
#  791,
#  792,
#  795,
#  797,
#  798,
#  800,
#  801,
#  802,
#  803,
#  804,
#  805,
#  806,
#  807,
#  808,
#  810,
#  814,
#  817,
#  819,
#  820,
#  821,
#  822,
#  825,
#  828,
#  829,
#  833,
#  834,
#  835,
#  837,
#  838,
#  840,
#  841,
#  843,
#  846,
#  849,
#  851,
#  853,
#  858,
#  879,
#  884,
#  885,
#  887,
#  891,
#  894,
#  899,
#  917,
#  935,
#  948,
#  949,
#  969,
#  971,
#  973,
#  976,
#  978,
#  986,
#  987,
#  990,
#  991,
#  1008,
#  1032,
#  1050,
#  1067,
#  1068,
#  1115,
#  1116,
#  1117,
#  1120,
#  1122,
#  1124,
#  1125,
#  1131,
#  1133,
#  1135,
#  1136,
#  1138,
#  1144,
#  1146,
#  1154,
#  1160,
#  1162,
#  1164,
#  1167,
#  1170,
#  1175,
#  1178,
#  1181,
#  1182,
#  1185,
#  1187,
#  1190,
#  1192,
#  1193,
#  1194,
#  1197,
#  1199,
#  1200,
#  1201,
#  1206,
#  1207,
#  1208,
#  1213,
#  1215,
#  1216,
#  1217,
#  1218,
#  1220,
#  1222,
#  1223,
#  1224,
#  1228,
#  1230,
#  1232,
#  1233,
#  1240,
#  1243,
#  1244,
#  1253,
#  1265,
#  1269,
#  1270,
#  1272,
#  1280,
#  1284,
#  1292,
#  1298,
#  1311,
#  1313,
#  1314,
#  1317,
#  1331,
#  1338,
#  1343,
#  1344,
#  1345,
#  1351,
#  1359,
#  1390,
#  1391,
#  1393,
#  1396,
#  1402,
#  1414,
#  1418,
#  1428,
#  1438,
#  1441,
#  1471,
#  1474,
#  1499,
#  1501,
#  1502,
#  1514,
#  1516,
#  1521,
#  1525,
#  1535,
#  1540,
#  1541,
#  1546,
#  1550,
#  1560,
#  1563,
#  1564,
#  1566,
#  1571,
#  1572,
#  1573,
#  1575,
#  1576,
#  1581,
#  1587,
#  1588,
#  1589,
#  1591,
#  1594,
#  1605,
#  1607,
#  1619,
#  1628,
#  1636,
#  1638,
#  1641,
#  1645,
#  1652,
#  1658,
#  1659,
#  1660,
#  1671,
#  1672,
#  1689,
#  1691,
#  1697,
#  1700,
#  1704,
#  1707,
#  1711,
#  1715,
#  1719,
#  1720,
#  1721,
#  1724,
#  1725,
#  1730,
#  1731,
#  1732,
#  1734,
#  1735,
#  1739,
#  1740,
#  1746,
#  1749,
#  1752,
#  1757,
#  1765,
#  1768,
#  1778,
#  1788,
#  1790,
#  1795,
#  1803,
#  1804,
#  1827,
#  1834,
#  1835,
#  1836,
#  1855,
#  1857,
#  1861,
#  1863,
#  1864,
#  1871,
#  1874,
#  1880,
#  1885,
#  1887,
#  1892,
#  1894,
#  1898,
#  1901,
#  1902,
#  1905,
#  1907,
#  1908,
#  1909,
#  1910,
#  1912,
#  1913,
#  1915,
#  1917,
#  1919,
#  1920,
#  1921,
#  1922,
#  1925,
#  1928,
#  1931,
#  1932,
#  1934,
#  1935,
#  1937,
#  1939,
#  1943,
#  1944,
#  1946,
#  1947,
#  1948,
#  1950,
#  1952,
#  1953,
#  1954,
#  1957,
#  1960,
#  1961,
#  1962,
#  1964,
#  1965,
#  1966,
#  1969,
#  1970,
#  1971,
#  1973,
#  1974,
#  1976,
#  1977,
#  1980,
#  1982,
#  1994,
#  1999,
#  2005,
#  2006,
#  2021,
#  2028,
#  2029,
#  2050,
#  2051,
#  2053,
#  2076,
#  2077,
#  2094,
#  2098,
#  2104,
#  2108,
#  2109,
#  2120,
#  2128,
#  2140,
#  2144,
#  2148,
#  2161,
#  2163,
#  2218,
#  2241,
#  2253,
#  2260,
#  2269,
#  2274,
#  2275,
#  2292,
#  2296,
#  2300,
#  2305,
#  2314,
#  2315,
#  2317,
#  2323,
#  2333,
#  2338,
#  2343,
#  2347,
#  2348,
#  2349,
#  2359,
#  2361,
#  2373,
#  2374,
#  2380,
#  2388,
#  2391,
#  2394,
#  2398,
#  2402,
#  2405,
#  2411,
#  2413,
#  2415,
#  2418,
#  2428,
#  2429,
#  2430,
#  2434,
#  2437,
#  2438,
#  2461,
#  2465,
#  2466,
#  2469,
#  2470,
#  2471,
#  2474,
#  2475,
#  2476,
#  2478,
#  2480,
#  2481,
#  2482,
#  2483,
#  2484,
#  2486,
#  2489,
#  2492,
#  2493,
#  2494,
#  2506,
#  2507,
#  2510,
#  2514,
#  2521,
#  2523,
#  2524,
#  2525,
#  2528,
#  2530,
#  2531,
#  2533,
#  2536,
#  2540,
#  2541,
#  2542,
#  2544,
#  2548,
#  2549,
#  2551,
#  2553,
#  2554,
#  2566,
#  2571,
#  2572,
#  2583,
#  2587,
#  2594,
#  2600,
#  2608,
#  2616,
#  2630,
#  2639,
#  2645,
#  2647,
#  2648,
#  2649,
#  2650,
#  2652,
#  2657,
#  2661,
#  2662,
#  2663,
#  2666,
#  2668,
#  2670,
#  2674,
#  2675,
#  2676,
#  2678,
#  2681,
#  2684,
#  2686,
#  2687,
#  2688,
#  2690,
#  2691,
#  2699,
#  2700,
#  2702,
#  2703,
#  2707,
#  2708,
#  2710,
#  2712,
#  2713,
#  2718,
#  2719,
#  2720,
#  2721,
#  2736,
#  2737,
#  2745,
#  2752,
#  2755,
#  2766,
#  2772,
#  2773,
#  2778,
#  2783,
#  2795,
#  2805,
#  2823,
#  2828,
#  2832,
#  2834,
#  2838,
#  2845,
#  2864,
#  2865,
#  2871,
#  2873,
#  2876,
#  2877,
#  2879,
#  2880,
#  2887,
#  2890,
#  2891,
#  2892,
#  2898,
#  2899,
#  2902,
#  2904,
#  2906,
#  2912,
#  2913,
#  2926,
#  2928,
#  2941,
#  2951,
#  2955,
#  2957,
#  2974,
#  2977,
#  2979,
#  3008,
#  3026,
#  3030,
#  3033,
#  3034,
#  3047,
#  3048,
#  3050,
#  3058,
#  3066,
#  3068,
#  3069,
#  3071,
#  3073,
#  3074,
#  3075,
#  3078,
#  3079,
#  3086,
#  3087,
#  3088,
#  3089,
#  3092,
#  3093,
#  3094,
#  3096,
#  3097,
#  3102,
#  3109,
#  3115,
#  3125,
#  3135,
#  3144,
#  3149,
#  3152,
#  3157,
#  3165,
#  3168,
#  3173,
#  3175,
#  3198,
#  3215,
#  3216,
#  3222,
#  3224,
#  3228,
#  3234,
#  3237,
#  3251,
#  3253,
#  3257,
#  3262,
#  3265,
#  3267,
#  3275,
#  3291,
#  3292,
#  3302,
#  3303,
#  3310,
#  3311,
#  3314,
#  3323,
#  3329,
#  3345,
#  3351,
#  3354,
#  3374,
#  3383,
#  3390,
#  3392,
#  3396,
#  3397,
#  3417,
#  3418,
#  3419,
#  3436,
#  3439,
#  3446,
#  3451,
#  3453,
#  3454,
#  3455,
#  3463,
#  3467,
#  3474,
#  3480,
#  3485,
#  3497,
#  3503,
#  3505,
#  3507,
#  3510,
#  3515,
#  3518,
#  3519,
#  3521,
#  3532,
#  3536,
#  3561,
#  3563,
#  3567,
#  3568,
#  3570,
#  3574,
#  3590,
#  3591,
#  3603,
#  3604,
#  3605,
#  3608,
#  3620,
#  3626,
#  3639,
#  3658,
#  3660,
#  3663,
#  3665,
#  3666,
#  3678,
#  3712,
#  3717,
#  3718,
#  3741,
#  3762,
#  3764,
#  3775,
#  3780,
#  3781,
#  3782,
#  3783,
#  3787,
#  3796,
#  3804,
#  3814,
#  3832,
#  3844,
#  3849,
#  3861,
#  3898,
#  3968,
#  4133,
#  4193,
#  4198,
#  4199,
#  4200,
#  4202,
#  4212,
#  4215,
#  4216,
#  4218,
#  4219,
#  4220,
#  4222,
#  4223,
#  4226,
#  4229,
#  4230,
#  4237,
#  4238,
#  4239,
#  4243,
#  4244,
#  4248,
#  4250,
#  4253,
#  4256,
#  4257,
#  4258,
#  4265,
#  4267,
#  4269,
#  4270,
#  4274,
#  4281,
#  4282,
#  4296,
#  4306,
#  4308,
#  4309,
#  4310,
#  4314,
#  4319,
#  4332,
#  4334,
#  4338,
#  4343,
#  4354,
#  4358,
#  4365,
#  4374,
#  4375,
#  4381,
#  4382,
#  4388,
#  4389,
#  4396,
#  4409,
#  4426,
#  4428,
#  4436,
#  4437,
#  4445,
#  4452,
#  4453,
#  4454,
#  4457,
#  4461,
#  4485,
#  4496,
#  4497,
#  4502,
#  4511,
#  4526,
#  4531,
#  4540,
#  4543,
#  4570,
#  4576,
#  4584,
#  4591,
#  4594,
#  4620,
#  4631,
#  4636,
#  4638,
#  4640,
#  4642,
#  4647,
#  4648,
#  4650,
#  4651,
#  4652,
#  4654,
#  4658,
#  4660,
#  4661,
#  4663,
#  4665,
#  4666,
#  4667,
#  4668,
#  4672,
#  4673,
#  4678,
#  4686,
#  4688,
#  4696,
#  4699,
#  4701,
#  4704,
#  4711,
#  4716,
#  4718,
#  4729,
#  4736,
#  4737,
#  4749,
#  4758,
#  4765,
#  4766,
#  4773,
#  4778,
#  4782,
#  4783,
#  4788,
#  4789,
#  4790,
#  4801,
#  4803,
#  4804,
#  4805,
#  4808,
#  4809,
#  4811,
#  4816,
#  4819,
#  4821,
#  4825,
#  4836,
#  4839,
#  4842,
#  4843,
#  4845,
#  4847,
#  4849,
#  4850,
#  4851,
#  4853,
#  4855,
#  4857,
#  4861,
#  4867,
#  4869,
#  4876,
#  4877,
#  4879,
#  4884,
#  4885,
#  4887,
#  4893,
#  4894,
#  4895,
#  4896,
#  4897,
#  4900,
#  4916,
#  4920,
#  4922,
#  4932,
#  4934,
#  4936,
#  4938,
#  4949,
#  4961,
#  4965,
#  4966,
#  4975,
#  4976,
#  4980,
#  4981,
#  4983,
#  4996,
#  5005,
#  5006,
#  5014,
#  5017,
#  5018,
#  5021,
#  5031,
#  5036,
#  5049,
#  5050,
#  5052,
#  5066,
#  5080,
#  5083,
#  5084,
#  5087,
#  5089,
#  5098,
#  5104,
#  5132,
#  5143,
#  5154,
#  5157,
#  5164,
#  5166,
#  5169,
#  5180,
#  5181,
#  5186,
#  5189,
#  5196,
#  5204,
#  5208,
#  5210,
#  5228,
#  5230,
#  5234,
#  5235,
#  5240,
#  5242,
#  5247,
#  5248,
#  5263,
#  5265,
#  5266,
#  5287,
#  5289,
#  5293,
#  5294,
#  5295,
#  5300,
#  5308,
#  5321,
#  5331,
#  5333,
#  5350,
#  5358,
#  5359,
#  5368,
#  ...]

# %%
data = data.drop(no_lat)

# %%
data['lat'] = data['location'].apply(lambda x: x['latitude'])

# %%
data['lon'] = data['location'].apply(lambda x: x['longitude'])

# %%
data.head(3)
# Out:
#         id dist                                     type  \
# 0  3977347   26  Building Residential Rehab Storm Damage
# 1  3963014    5               Building Residential - New
# 2  3979526   18              Building Commercial - Rehab
#
#                               subtype                     date    cost  \
# 0             Single Family Residence  2021-06-21T00:00:00.000   40000
# 1             Single Family Residence  2021-05-05T00:00:00.000  292188
# 2  Retail, Department / Retail Stores  2021-06-21T00:00:00.000  234501
#
#             address                                            purpose  \
# 0    5045  SUTER DR  to conduct general repairs to existing residen...
# 1     1807  JOY CIR  to construct a single family residence with 24...
# 2  2707  12TH AVE S  TO CONDUCT INTERIOR RENOVATIONS FOR NEW TENANT...
#
#                                             location        lat         lon
# 0  {'latitude': '36.068916', 'longitude': '-86.73...  36.068916  -86.738966
# 1  {'latitude': '36.202582', 'longitude': '-86.76...  36.202582  -86.760444
# 2  {'latitude': '36.122666', 'longitude': '-86.79...  36.122666   -86.79007

# %%
data = data.drop(columns = ['location'])

# %%
data['geometry'] = data.apply(lambda x: Point((float(x.lon), 
                                              float(x.lat))), axis = 1)
data.head(3)
# Out:
#         id dist                                     type  \
# 0  3977347   26  Building Residential Rehab Storm Damage
# 1  3963014    5               Building Residential - New
# 2  3979526   18              Building Commercial - Rehab
#
#                               subtype                     date    cost  \
# 0             Single Family Residence  2021-06-21T00:00:00.000   40000
# 1             Single Family Residence  2021-05-05T00:00:00.000  292188
# 2  Retail, Department / Retail Stores  2021-06-21T00:00:00.000  234501
#
#             address                                            purpose  \
# 0    5045  SUTER DR  to conduct general repairs to existing residen...
# 1     1807  JOY CIR  to construct a single family residence with 24...
# 2  2707  12TH AVE S  TO CONDUCT INTERIOR RENOVATIONS FOR NEW TENANT...
#
#          lat         lon                              geometry
# 0  36.068916  -86.738966          POINT (-86.738966 36.068916)
# 1  36.202582  -86.760444  POINT (-86.76044400000001 36.202582)
# 2  36.122666   -86.79007           POINT (-86.79007 36.122666)

# %%
data_geo = gpd.GeoDataFrame(data, 
                           crs = )

# %% [markdown]
# ## API Call for City Council GIS outlines to create geodataframe

# %%
endpoint = 'https://data.nashville.gov/resource/iw7r-m8qr.json'

# %%
#the only params we need are the columns, I want the ivr_trk as the unique id, type and subtype description, date issued, value of construction, 
#address, zip, council district, purpose, mapped location
#also set the limit high so the downloads don't cut off
params = {'$select': 'boundary, council_district'}
response = requests.get(endpoint, params = params)
response.status_code

data = response.json()
data = pd.DataFrame(data)
print(data.shape)
data.head(3)
